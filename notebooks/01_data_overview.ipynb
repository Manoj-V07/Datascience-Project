# %% [markdown]
# # Dataset Overview

# %%
import sys, os; sys.path.append(r'd:\Data-Science-Project'); from src.analysis.eda_utils import load_processed_data
df, events, hubs = load_processed_data()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5160 entries, 0 to 5159
# Data columns (total 47 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Assessment_ID                    5160 non-null   object
#  1   Event_ID                         5160 non-null   object
#  2   Location_ID                      5160 non-null   object
#  3   District                         5160 non-null   object
#  4   Response_Zone                    5160 non-null   object
#  5   Assessment_Window                5160 non-null   object
#  6   Hours_Since_Disaster             5160 non-null   int64
#  7   Simulation_ID                    5160 non-null   object
#  8   Latitude                         5160 non-null   float64
#  9   Longitude                        5160 non-null   float64
#  10  Hub_ID                           5160 non-null   object
#  11  Distance_to_Hub_km               5160 non-null   float64
# ...
