# %% [markdown]
# # Temporal Analysis

# %%
import sys; sys.path.append(r'd:\Data-Science-Project')
import matplotlib.pyplot as plt, seaborn as sns
from src.analysis.plot_utils import setup_style, save_plot
from src.analysis.eda_utils import load_processed_data
setup_style()
df, _, _ = load_processed_data()

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.lineplot(data=df, x='Hours_Since_Disaster', y='Food_Required_packets', hue='Disaster_Type', estimator='mean', errorbar=None, ax=ax)
ax.set_title('Food Demand Progression over 72 Hours')
save_plot(fig, '04_food_temporal.png')
