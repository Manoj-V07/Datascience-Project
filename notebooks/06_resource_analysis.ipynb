# %% [markdown]
# # Resource Analysis

# %%
import sys; sys.path.append(r'd:\Data-Science-Project')
import matplotlib.pyplot as plt, seaborn as sns
from src.analysis.plot_utils import setup_style, save_plot
from src.analysis.eda_utils import load_processed_data
setup_style()
df, _, _ = load_processed_data()

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.scatterplot(data=df, x='Population_Affected_Est', y='Food_Required_packets', alpha=0.5, ax=ax)
ax.set_title('Affected Population vs Food Required')
save_plot(fig, '06_pop_vs_food.png')
